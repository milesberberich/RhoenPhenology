# %% [markdown]
# ## Functions / libaries

# %%
from phen_loop import *

# %% [markdown]
# ## Year loop

# %%
phen_loop(2006, 2009, r"C:\Users\miles\OneDrive\Dokumente\EAGLE SoSe\Linking science\results\phenology\16day_60_nofilter", class_codes = [60], Save = True, dynamik_landcover= "False", temporal_res="16", window_size=5, smoothing="True")
# Out:
# phenology will be calculated on the basis of NDVI for the years from 2006 to 2008.
# The landcover classes ['Tree cover, broadleaved, deciduous, closed to open (>15%)'] will be used
# Static landcover data from 2022 will be used.
# Searching LC catalog
# landcover loaded
# Smoothing will be used.
# Processing NDVI:   0%|          | 0/4 [00:00<?, ?it/s]
# Searching MODIS catalog for 16 day resolution
# Found 48 items (19.96 MB
# datacube clipped
# Modis clipped to landcover.
# Timeseries was smoothed.
# datacube clipped
# Phenology indicators were calculated.
# Searching MODIS catalog for 16 day resolution
# Found 48 items (19.96 MB
# datacube clipped
# Modis clipped to landcover.
# Timeseries was smoothed.
# datacube clipped
# Phenology indicators were calculated.
# Searching MODIS catalog for 16 day resolution
# Found 48 items (19.96 MB
# datacube clipped
# Modis clipped to landcover.
# Timeseries was smoothed.
# datacube clipped
# Phenology indicators were calculated.
# ...
