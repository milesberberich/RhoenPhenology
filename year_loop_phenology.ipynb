# %% [markdown]
# ## Functions / libaries

# %%
from phen_loop import *

# %% [markdown]
# ## Year loop

# %%
phen_loop(2000, 2025, r"C:\Users\miles\OneDrive\Dokumente\EAGLE SoSe\Linking science\results\phenology\16day_60_slopesavgol", class_codes = [60], Save = True, dynamik_landcover= "True", temporal_res="16", window_size=5, smoothing="True")
# Out:
# phenology will be calculated on the basis of NDVI for the years from 2000 to 2024.
# The landcover classes ['Tree cover, broadleaved, deciduous, closed to open (>15%)'] will be used
# Dynamic landcover will be used.
# Smoothing will be used.
# Processing NDVI:   0%|          | 0/26 [00:00<?, ?it/s]
# Searching MODIS catalog for 16 day resolution
# Found 20 items (8.32 MB
# Searching LC catalog
# landcover loaded
# datacube clipped
# Modis clipped to landcover.
# Timeseries was smoothed.
# Phenology indicators were calculated.
# Searching MODIS catalog for 16 day resolution
# Found 24 items (9.98 MB
# Searching LC catalog
# landcover loaded
# datacube clipped
# Modis clipped to landcover.
# Timeseries was smoothed.
# Phenology indicators were calculated.
# Searching MODIS catalog for 16 day resolution
# Found 36 items (14.97 MB
# Searching LC catalog
# landcover loaded
# datacube clipped
# Modis clipped to landcover.
# Timeseries was smoothed.
# Phenology indicators were calculated.
# ...
