# %% [markdown]
# ## Calculate phenology based on MODIS for several years, similar to analysis.ipynb

# %% [markdown]
# ## Functions / libaries

# %%
from functions.phen_loop import *

# %% [markdown]
# ## Year/LC loop

# %%
LC_LOOP = True

if LC_LOOP:

    wanted_landcover = {"crops": [10,11], "deciduous": [60,61,62], "needleleaved":[70], "mixedforest":[90]}

    for lc, lc_code in wanted_landcover.items():

        phen_loop(2000, 2025, f"C:/Users/miles/OneDrive/Dokumente/EAGLE SoSe/Linking science/results/phenology/16day_{lc_code}_{lc}_slopesavgol", class_codes = lc_code, Save = True, dynamik_landcover= "True", temporal_res="16", window_size=5, smoothing="True")

        print(f"{lc} was calculated")

else:

    phen_loop(2000, 2025, r"C:\Users\miles\OneDrive\Dokumente\EAGLE SoSe\Linking science\results\phenology\16day_[60, 61, 62]_deciduous_slopesavgol", class_codes = [60, 61, 62], Save = True, dynamik_landcover= "True", temporal_res="16", window_size=5, smoothing="True")
# Out:
# phenology will be calculated on the basis of NDVI for the years from 2000 to 2024.
# The landcover classes ['Cropland, rainfed', 'Herbaceous cover'] will be used
# Dynamic landcover will be used.
# Smoothing will be used.
# Processing NDVI:   0%|          | 0/26 [00:00<?, ?it/s]
# Searching MODIS catalog for 16 day resolution
# Found 20 items (8.32 MB
# Searching LC catalog
# landcover loaded
# datacube clipped
# Modis clipped to landcover.
# Timeseries was smoothed.
# Phenology indicators were calculated.
# Searching MODIS catalog for 16 day resolution
# Found 24 items (9.98 MB
# Searching LC catalog
# landcover loaded
# datacube clipped
# Modis clipped to landcover.
# Timeseries was smoothed.
# Phenology indicators were calculated.
# Searching MODIS catalog for 16 day resolution
# Found 36 items (14.97 MB
# Searching LC catalog
# landcover loaded
# datacube clipped
# Modis clipped to landcover.
# Timeseries was smoothed.
# Phenology indicators were calculated.
# ...
