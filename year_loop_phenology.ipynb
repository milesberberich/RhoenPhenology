# %% [markdown]
# ## Functions / libaries

# %%
from phen_loop import *

# %% [markdown]
# ## Year/LC loop

# %%
LC_LOOP = True

if LC_LOOP:

    wanted_landcover = {"crops": [10,11], "deciduous": [60,61,62], "needleleaved":[70], "mixedforest":[90]}

    for lc, lc_code in wanted_landcover.items():

        phen_loop(2000, 2025, f"C:/Users/miles/OneDrive/Dokumente/EAGLE SoSe/Linking science/results/phenology/16day_{lc_code}_{lc}_slopesavgol", class_codes = lc_code, Save = True, dynamik_landcover= "True", temporal_res="16", window_size=5, smoothing="True")

        print(f"{lc} was calculated")

else:

    phen_loop(2000, 2025, r"C:\Users\miles\OneDrive\Dokumente\EAGLE SoSe\Linking science\results\phenology\16day_60_slopesavgol", class_codes = [60], Save = True, dynamik_landcover= "True", temporal_res="16", window_size=5, smoothing="True")
# Out:
# C:/Users/miles/OneDrive/Dokumente/EAGLE SoSe/Linking science/results/phenology/16day_[10, 11]_crops_slopesavgol
# crops was calculated
# C:/Users/miles/OneDrive/Dokumente/EAGLE SoSe/Linking science/results/phenology/16day_[60, 61, 62]_deciduous_slopesavgol
# deciduous was calculated
# C:/Users/miles/OneDrive/Dokumente/EAGLE SoSe/Linking science/results/phenology/16day_[70]_needleleaved_slopesavgol
# needleleaved was calculated
# C:/Users/miles/OneDrive/Dokumente/EAGLE SoSe/Linking science/results/phenology/16day_[90]_mixedforest_slopesavgol
# mixedforest was calculated
