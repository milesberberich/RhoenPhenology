# %% [markdown]
# ## Functions / libaries

# %%
from phen_loop import *

# %% [markdown]
# ## Year loop

# %%
phen_loop(2000, 2025, r"C:\Users\miles\OneDrive\Dokumente\EAGLE SoSe\Linking science\results\phenology\forest_loop_static", index = "NDVI", class_codes = [60, 70, 90], Save = True, dynamik_landcover= "False")
# Out:
# phenology will be calculated on the basis of NDVI for the years from 2000 to 2024.
# The landcover classes ['Tree cover, broadleaved, deciduous, closed to open (>15%)', 'Tree cover, needleleaved, evergreen, closed to open (>15%)', 'Tree cover, mixed leaf type (broadleaved and needleleaved)'] will be used
# Static landcover data from 2022 will be used.
# Processing NDVI:   0%|          | 0/26 [00:00<?, ?it/s]
# Searching MODIS catalog
# Found 20 items (8.32 MB
# Searching LC catalog
# landcover loaded
# datacube clipped
#       Phenology...
# C:\Users\miles\OneDrive\Dokumente\EAGLE SoSe\Linking science\RhoenPhenology\.venv\Lib\site-packages\xarray\core\duck_array_ops.py:268: RuntimeWarning: invalid value encountered in cast
#   return data.astype(dtype, **kwargs)
# C:\Users\miles\OneDrive\Dokumente\EAGLE SoSe\Linking science\RhoenPhenology\.venv\Lib\site-packages\xarray\core\duck_array_ops.py:268: RuntimeWarning: invalid value encountered in cast
# ...

# %%
phen_loop(2000, 2025, r"C:\Users\miles\OneDrive\Dokumente\EAGLE SoSe\Linking science\results\phenology\forest_loop_dynamic", index = "NDVI", class_codes = [60, 70, 90], Save = True, dynamik_landcover= "True")
