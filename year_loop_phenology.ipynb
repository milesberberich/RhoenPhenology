# %% [markdown]
# ## Functions / libaries

# %%
from phen_loop import *

# %% [markdown]
# ## Year loop

# %%
phen_loop(2020, 2025, r"C:\Users\miles\OneDrive\Dokumente\EAGLE SoSe\Linking science\results\phenology\forest_loop_static_8days_smoothed", class_codes = [60], Save = True, dynamik_landcover= "False", temporal_res="8", window_size=4, smoothing="True")
# Out:
# phenology will be calculated on the basis of NDVI for the years from 2020 to 2024.
# The landcover classes ['Tree cover, broadleaved, deciduous, closed to open (>15%)'] will be used
# Static landcover data from 2022 will be used.
# Searching LC catalog
# landcover loaded
# Smoothing will be used.
# Processing NDVI:   0%|          | 0/6 [00:00<?, ?it/s]
# Searching MODIS catalog for 8 day resolution...
# Found 94 items (19.54 MB)
# datacube clipped
#       Phenology...
# C:\Users\miles\OneDrive\Dokumente\EAGLE SoSe\Linking science\RhoenPhenology\.venv\Lib\site-packages\xarray\core\duck_array_ops.py:268: RuntimeWarning: invalid value encountered in cast
#   return data.astype(dtype, **kwargs)
#          POS
#          EOS
#          Trough
#          vSOS
#          vPOS
#          vEOS
#          LOS
#          AOS
#          ROG
#          ROS
# datacube clipped
# ...
