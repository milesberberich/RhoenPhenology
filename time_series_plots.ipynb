# %% [markdown]
# ## Import functions

# %%
from functions.plot_functions import *

# %% [markdown]
# ## Plotting

# %%
ridgeplot(r"C:\Users\miles\OneDrive\Dokumente\EAGLE SoSe\Linking science\results\phenology\forest_loop_annuallc", metric = "SOS", band = 1)
