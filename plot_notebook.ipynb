# %%
from functions.plot_functions import *

# %%
ridgeplot(r"C:\Users\miles\OneDrive\Dokumente\EAGLE SoSe\Linking science\results\phenology\16day_60_slopesavgol", metric="SOS", band=1)
ridgeplot(r"C:\Users\miles\OneDrive\Dokumente\EAGLE SoSe\Linking science\results\phenology\16day_60_slopesavgol", metric = "EOS", band=2)
ridgeplot(r"C:\Users\miles\OneDrive\Dokumente\EAGLE SoSe\Linking science\results\phenology\16day_60_slopesavgol", metric="LOS", band=3)
