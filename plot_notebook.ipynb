# %%
from plot_functions import *

# %%
ridgeplot(r"C:\Users\miles\OneDrive\Dokumente\EAGLE SoSe\Linking science\results\phenology\8day_60", metric="SOS", band=1)
ridgeplot(r"C:\Users\miles\OneDrive\Dokumente\EAGLE SoSe\Linking science\results\phenology\8day_60", metric="EOS", band=2)
ridgeplot(r"C:\Users\miles\OneDrive\Dokumente\EAGLE SoSe\Linking science\results\phenology\8day_60", metric="DOS", band=3)
