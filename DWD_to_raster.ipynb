# %% [markdown]
# ## Script to convert DWD phenology data downloaded from https://opendata.dwd.de/climate_environment/CDC/grids_germany/annual/phenology as .asc to .tiff

# %% [markdown]
# ## Functions

# %%
from functions.asc_to_raster import *
from pathlib import Path

# %% [markdown]
# ## List files

# %%
file_list = [str(f.resolve()) for f in Path(r"C:\Users\miles\OneDrive\Dokumente\EAGLE SoSe\Linking science\DWD\beech_spring").iterdir() if f.is_file()]

# %% [markdown]
# ## Looping

# %%
for f in file_list:

    year = Path(f).stem[-4:]
    asc_to_raster(asc_path=f, output_path=f"C:/Users/miles/OneDrive/Dokumente/EAGLE SoSe/Linking science/DWD/beech_raster_spring_long/beech_{year}.tif", clip_geojson=r"C:\Users\miles\OneDrive\Dokumente\EAGLE SoSe\Linking science\gis\geodata\bioreservat_rhön.geojson")
    print(f"{year} was converted to raster.")
# Out:
# 1992 was converted to raster.
# 1993 was converted to raster.
# 1994 was converted to raster.
# 1995 was converted to raster.
# 1996 was converted to raster.
# 1997 was converted to raster.
# 1998 was converted to raster.
# 1999 was converted to raster.
# 2000 was converted to raster.
# 2001 was converted to raster.
# 2002 was converted to raster.
# 2003 was converted to raster.
# 2004 was converted to raster.
# 2005 was converted to raster.
# 2006 was converted to raster.
# 2007 was converted to raster.
# 2008 was converted to raster.
# 2009 was converted to raster.
# 2010 was converted to raster.
# 2011 was converted to raster.
# 2012 was converted to raster.
# 2013 was converted to raster.
# 2014 was converted to raster.
# 2015 was converted to raster.
# 2016 was converted to raster.
# 2017 was converted to raster.
# 2018 was converted to raster.
# 2019 was converted to raster.
# 2020 was converted to raster.
# 2021 was converted to raster.
# 2022 was converted to raster.
# ...
