# %% [markdown]
# ## Functions

# %%
from asc_to_raster import *
from pathlib import Path

# %% [markdown]
# ## List files

# %%
file_list = [str(f.resolve()) for f in Path(r"C:\Users\miles\OneDrive\Dokumente\EAGLE SoSe\Linking science\DWD\beech").iterdir() if f.is_file()]

# %% [markdown]
# ## Looping

# %%
for f in file_list:

    year = Path(f).stem[-4:]
    asc_to_raster(asc_path=f, output_path=f"C:/Users/miles/OneDrive/Dokumente/EAGLE SoSe/Linking science/DWD/beech_raster/beech_{year}.tif", crs="EPSG:31467")
    print(f"{year} was converted to raster.")
