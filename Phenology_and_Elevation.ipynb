# %% [markdown]
# ## Get functions

# %%
from get_srtm import *
from xarray_scatterplot import *
import rioxarray

# %% [markdown]
# ## Get SRTM

# %%
srtm = get_srtm(r"C:\Users\miles\OneDrive\Dokumente\EAGLE SoSe\Linking science\gis\geodata\bioreservat_rhön.geojson")
# Out:
# Searching catalog...

# %% [markdown]
# ## Get Phenology

# %%
Local = True

if Local == True:
